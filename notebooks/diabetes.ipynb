# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
# train_data_path = "../data/logs/run_0/breast_train/synth_aim_l1_eps_1.0.csv"
train_data_path = "../data/diabetes_train.csv"
test_path = "../data/diabetes_test.csv"

# %%
def train(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

# %%
def test(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return accuracy, f1

# %%
train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_path)

# %%
X_train = train_df.drop(columns=["Outcome"])
y_train = train_df["Outcome"]
X_test = test_df.drop(columns=["Outcome"])
y_test = test_df["Outcome"]

# %%
model = LogisticRegression(max_iter=1000, random_state=42)
model = train(model, X_train, y_train)

# %%
accuracy, f1 = test(model, X_test, y_test)

# %%
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.7532
# F1 Score: 0.5778

# %%
def run(train_path, test_path):
    train_df = pd.read_csv(train_path)
    test_df = pd.read_csv(test_path)

    X_train = train_df.drop(columns=["Outcome"])
    
    y_train = train_df["Outcome"]
    X_test = test_df.drop(columns=["Outcome"]).astype("float64")
    y_test = test_df["Outcome"]                                                                                      

    model = LogisticRegression(max_iter=1000, random_state=42, class_weight="balanced")
    model = train(model, X_train, y_train)
    accuracy, f1 = test(model, X_test, y_test)
    return accuracy, f1

# %% [markdown]
# ## Real Data

# %%
train_data_path = "../data/diabetes_train.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.7078
# F1 Score: 0.6018

# %%
train_data_path = "../data/logs/run_0/diabetes_train/synth_aim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6169
# F1 Score: 0.1194

# %% [markdown]
# ## FHAIM-L1

# %%
train_data_path = "../data/logs/run_0/diabetes_train/synth_fhaim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.4870
# F1 Score: 0.2330

# %% [markdown]
# ## AIM-L2

# %%
train_data_path = "../data/logs/run_0/diabetes_train/synth_aim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.4805
# F1 Score: 0.2727

# %% [markdown]
# ## FHAIM-L2

# %%
train_data_path = "../data/logs/run_0/diabetes_train/synth_fhaim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.4545
# F1 Score: 0.2075

# %% [markdown]
# # Run 1

# %% [markdown]
# ## AIM-L1

# %%
train_data_path = "../data/logs/run_1/diabetes_train/synth_aim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.5519
# F1 Score: 0.5369

# %% [markdown]
# ## FHAIM-L1

# %%
train_data_path = "../data/logs/run_1/diabetes_train/synth_fhaim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.4675
# F1 Score: 0.0889

# %% [markdown]
# ## AIM-L2

# %%
train_data_path = "../data/logs/run_1/diabetes_train/synth_aim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.5130
# F1 Score: 0.2574

# %% [markdown]
# ## FHAIM-L2

# %%
train_data_path = "../data/logs/run_1/diabetes_train/synth_fhaim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.5714
# F1 Score: 0.0294

# %% [markdown]
# # Run 2

# %% [markdown]
# ## AIM-L1

# %%
train_data_path = "../data/logs/run_2/diabetes_train/synth_aim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6364
# F1 Score: 0.2000

# %% [markdown]
# ## FHAIM-L1

# %%
train_data_path = "../data/logs/run_2/diabetes_train/synth_fhaim_l1_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6039
# F1 Score: 0.5120

# %% [markdown]
# ## AIM-L2

# %%
train_data_path = "../data/logs/run_2/diabetes_train/synth_aim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6948
# F1 Score: 0.3562

# %% [markdown]
# ## FHAIM-L2

# %%
train_data_path = "../data/logs/run_2/diabetes_train/synth_fhaim_l2_eps_1.0.csv"
test_path = "../data/diabetes_test.csv"
accuracy, f1 = run(train_data_path, test_path)
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.6623
# F1 Score: 0.0370
