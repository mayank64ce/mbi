# %%
import pandas as pd

# %% [markdown]
# ## Breast Cancer Dataset

# %%
cancer_train_path = "../data/breast_train.csv"
cancer_test_path = "../data/breast_test.csv"

# %%
df_cancer_train = pd.read_csv(cancer_train_path)
df_cancer_test = pd.read_csv(cancer_test_path)

# %%
df_cancer_train.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'class', 'age', 'menopause', 'tumor-size',
#        'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad',
#        'irradiat'],
#       dtype='object')

# %%
df_cancer_test.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'class', 'age', 'menopause', 'tumor-size',
#        'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad',
#        'irradiat'],
#       dtype='object')

# %%
df_cancer_train = df_cancer_train.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df_cancer_test = df_cancer_test.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
len(df_cancer_test)
# Out:
# 57

# %%
df_cancer_test.head()
# Out:
#    class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0    0.0  3.0        2.0         4.0        0.0        1.0        1.0     0.0
# 1    0.0  4.0        0.0         3.0        0.0        1.0        0.0     0.0
# 2    0.0  3.0        0.0         4.0        0.0        1.0        1.0     0.0
# 3    0.0  2.0        2.0         2.0        0.0        1.0        1.0     0.0
# 4    0.0  3.0        0.0         7.0        0.0        1.0        1.0     0.0
#
#    breast-quad  irradiat
# 0          2.0       0.0
# 1          2.0       0.0
# 2          2.0       0.0
# 3          2.0       0.0
# 4          2.0       0.0

# %%
len(df_cancer_train), len(df_cancer_test)
# Out:
# (228, 57)

# %%
# save
train_path = cancer_train_path.split("/")[-1]
test_path = cancer_test_path.split("/")[-1]

print(train_path, test_path)
# Out:
# breast_train.csv breast_test.csv

# %%
df_cancer_train.to_csv(train_path, index=False)

# %%
df_cancer_test.to_csv(test_path, index=False)
